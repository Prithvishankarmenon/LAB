# %% [markdown]
# # EXPERIMENT  4

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df=pd.read_csv("/home/s5ad2/Downloads/train_cars.csv")

# %%
df.head(5) # first 5 rows
# Out:
#          date  hour  demand
# 0  18-08-2018     9    91.0
# 1  18-08-2018    10    21.0
# 2  18-08-2018    13    23.0
# 3  18-08-2018    14   104.0
# 4  18-08-2018    15    81.0

# %%
df.tail(5) # last 5 rows
# Out:
#              date  hour  demand
# 18242  28-02-2021    19    95.0
# 18243  28-02-2021    20    88.0
# 18244  28-02-2021    21    39.0
# 18245  28-02-2021    22   104.0
# 18246  28-02-2021    23    85.0

# %%
df.count() # summarise cvs file
# Out:
# date      18247
# hour      18247
# demand    18243
# dtype: int64

# %%
df.isna() # check all rows for null values
# Out:
#         date   hour  demand
# 0      False  False   False
# 1      False  False   False
# 2      False  False   False
# 3      False  False   False
# 4      False  False   False
# ...      ...    ...     ...
# 18242  False  False   False
# 18243  False  False   False
# 18244  False  False   False
# 18245  False  False   False
# 18246  False  False   False
#
# [18247 rows x 3 columns]

# %%
df.isna().sum() # summarise isna()
# Out:
# date      0
# hour      0
# demand    4
# dtype: int64

# %%
df.dtypes # all data types present
# Out:
# date       object
# hour        int64
# demand    float64
# dtype: object

# %%
df['demand']=df['demand'].fillna(df['demand'].mean()) # Replacing all null values in demand with mean of demand column

# %%
df.isna().sum()
# Out:
# date      0
# hour      0
# demand    0
# dtype: int64

# %%
df['date']=pd.to_datetime(df['date']) # converting date from being a 'object'type to date type data

# %%
df.dtypes
# Out:
# date      datetime64[ns]
# hour               int64
# demand           float64
# dtype: object

# %%
df['year']=df['date'].apply(lambda x:x.year) # creating a new column

# %%
df
# Out:
#             date  hour  demand  year
# 0     2018-08-18     9    91.0  2018
# 1     2018-08-18    10    21.0  2018
# 2     2018-08-18    13    23.0  2018
# 3     2018-08-18    14   104.0  2018
# 4     2018-08-18    15    81.0  2018
# ...          ...   ...     ...   ...
# 18242 2021-02-28    19    95.0  2021
# 18243 2021-02-28    20    88.0  2021
# 18244 2021-02-28    21    39.0  2021
# 18245 2021-02-28    22   104.0  2021
# 18246 2021-02-28    23    85.0  2021
#
# [18247 rows x 4 columns]

# %%
df['month']=df['date'].apply(lambda x:x.month)

# %%
df
# Out:
#             date  hour  demand  year  month
# 0     2018-08-18     9    91.0  2018      8
# 1     2018-08-18    10    21.0  2018      8
# 2     2018-08-18    13    23.0  2018      8
# 3     2018-08-18    14   104.0  2018      8
# 4     2018-08-18    15    81.0  2018      8
# ...          ...   ...     ...   ...    ...
# 18242 2021-02-28    19    95.0  2021      2
# 18243 2021-02-28    20    88.0  2021      2
# 18244 2021-02-28    21    39.0  2021      2
# 18245 2021-02-28    22   104.0  2021      2
# 18246 2021-02-28    23    85.0  2021      2
#
# [18247 rows x 5 columns]

# %%
df['day']=df['date'].apply(lambda x:x.day)

# %%
df
# Out:
#             date  hour  demand  year  month  day
# 0     2018-08-18     9    91.0  2018      8   18
# 1     2018-08-18    10    21.0  2018      8   18
# 2     2018-08-18    13    23.0  2018      8   18
# 3     2018-08-18    14   104.0  2018      8   18
# 4     2018-08-18    15    81.0  2018      8   18
# ...          ...   ...     ...   ...    ...  ...
# 18242 2021-02-28    19    95.0  2021      2   28
# 18243 2021-02-28    20    88.0  2021      2   28
# 18244 2021-02-28    21    39.0  2021      2   28
# 18245 2021-02-28    22   104.0  2021      2   28
# 18246 2021-02-28    23    85.0  2021      2   28
#
# [18247 rows x 6 columns]

# %%
df.dtypes
# Out:
# date      datetime64[ns]
# hour               int64
# demand           float64
# year               int64
# month              int64
# day                int64
# dtype: object

# %%
df['dayofweek']=df['date'].apply(lambda x:x.dayofweek)

# %%
df
# Out:
#             date  hour  demand  year  month  day  dayofweek
# 0     2018-08-18     9    91.0  2018      8   18          5
# 1     2018-08-18    10    21.0  2018      8   18          5
# 2     2018-08-18    13    23.0  2018      8   18          5
# 3     2018-08-18    14   104.0  2018      8   18          5
# 4     2018-08-18    15    81.0  2018      8   18          5
# ...          ...   ...     ...   ...    ...  ...        ...
# 18242 2021-02-28    19    95.0  2021      2   28          6
# 18243 2021-02-28    20    88.0  2021      2   28          6
# 18244 2021-02-28    21    39.0  2021      2   28          6
# 18245 2021-02-28    22   104.0  2021      2   28          6
# 18246 2021-02-28    23    85.0  2021      2   28          6
#
# [18247 rows x 7 columns]

# %%
df['isquarterdate']=df['date'].apply(lambda x:x.quarter)

# %%
df
# Out:
#             date  hour  demand  year  month  day  dayofweek  isquarterdate
# 0     2018-08-18     9    91.0  2018      8   18          5              3
# 1     2018-08-18    10    21.0  2018      8   18          5              3
# 2     2018-08-18    13    23.0  2018      8   18          5              3
# 3     2018-08-18    14   104.0  2018      8   18          5              3
# 4     2018-08-18    15    81.0  2018      8   18          5              3
# ...          ...   ...     ...   ...    ...  ...        ...            ...
# 18242 2021-02-28    19    95.0  2021      2   28          6              1
# 18243 2021-02-28    20    88.0  2021      2   28          6              1
# 18244 2021-02-28    21    39.0  2021      2   28          6              1
# 18245 2021-02-28    22   104.0  2021      2   28          6              1
# 18246 2021-02-28    23    85.0  2021      2   28          6              1
#
# [18247 rows x 8 columns]

# %%
df['isweekend']=df['dayofweek'].apply(lambda x:1 if x>4 else 0)

# %%
df
# Out:
#             date  hour  demand  year  month  day  dayofweek  isquarterdate  \
# 0     2018-08-18     9    91.0  2018      8   18          5              3
# 1     2018-08-18    10    21.0  2018      8   18          5              3
# 2     2018-08-18    13    23.0  2018      8   18          5              3
# 3     2018-08-18    14   104.0  2018      8   18          5              3
# 4     2018-08-18    15    81.0  2018      8   18          5              3
# ...          ...   ...     ...   ...    ...  ...        ...            ...
# 18242 2021-02-28    19    95.0  2021      2   28          6              1
# 18243 2021-02-28    20    88.0  2021      2   28          6              1
# 18244 2021-02-28    21    39.0  2021      2   28          6              1
# 18245 2021-02-28    22   104.0  2021      2   28          6              1
# 18246 2021-02-28    23    85.0  2021      2   28          6              1
#
#        isweekend
# 0              1
# 1              1
# ...

# %%
df.drop(['date'],axis=1,inplace=True) # Rest of the condition so as to modify the same csv and to not to create new

# %%
df
# Out:
#        hour  demand  year  month  day  dayofweek  isquarterdate  isweekend
# 0         9    91.0  2018      8   18          5              3          1
# 1        10    21.0  2018      8   18          5              3          1
# 2        13    23.0  2018      8   18          5              3          1
# 3        14   104.0  2018      8   18          5              3          1
# 4        15    81.0  2018      8   18          5              3          1
# ...     ...     ...   ...    ...  ...        ...            ...        ...
# 18242    19    95.0  2021      2   28          6              1          1
# 18243    20    88.0  2021      2   28          6              1          1
# 18244    21    39.0  2021      2   28          6              1          1
# 18245    22   104.0  2021      2   28          6              1          1
# 18246    23    85.0  2021      2   28          6              1          1
#
# [18247 rows x 8 columns]

# %%
def timeOfDay(n):
    if n in range(1,4):
        return "Late Night"
    elif n in range(4,7):
        return "Early Morning"
    elif n in range(7,12):
        return "Morning"
    elif n in range(12,15):
        return "After Noon"
    elif n in range(15,18):
        return "Evening"
    elif n in range(18,25) or n==0 :
        return "Night"

# %%
df['timeOfDay']=df['hour'].apply(lambda x:timeOfDay(x))

# %%
df
# Out:
#        hour  demand  year  month  day  dayofweek  isquarterdate  isweekend  \
# 0         9    91.0  2018      8   18          5              3          1
# 1        10    21.0  2018      8   18          5              3          1
# 2        13    23.0  2018      8   18          5              3          1
# 3        14   104.0  2018      8   18          5              3          1
# 4        15    81.0  2018      8   18          5              3          1
# ...     ...     ...   ...    ...  ...        ...            ...        ...
# 18242    19    95.0  2021      2   28          6              1          1
# 18243    20    88.0  2021      2   28          6              1          1
# 18244    21    39.0  2021      2   28          6              1          1
# 18245    22   104.0  2021      2   28          6              1          1
# 18246    23    85.0  2021      2   28          6              1          1
#
#         timeOfDay
# 0         Morning
# 1         Morning
# ...

# %%
def monthToSeason(n):
    if n in [9,10,11]:
        return "Spring"
    elif n in [12,1,2]:
        return "Summer"
    elif n in [3,4,5]:
        return "Autumn"
    elif n in [6,7,8]:
        return "Winter"

# %%
df['Seasons']=df['month'].apply(lambda x:monthToSeason(x))

# %%
df
# Out:
#        hour  demand  year  month  day  dayofweek  isquarterdate  isweekend  \
# 0         9    91.0  2018      8   18          5              3          1
# 1        10    21.0  2018      8   18          5              3          1
# 2        13    23.0  2018      8   18          5              3          1
# 3        14   104.0  2018      8   18          5              3          1
# 4        15    81.0  2018      8   18          5              3          1
# ...     ...     ...   ...    ...  ...        ...            ...        ...
# 18242    19    95.0  2021      2   28          6              1          1
# 18243    20    88.0  2021      2   28          6              1          1
# 18244    21    39.0  2021      2   28          6              1          1
# 18245    22   104.0  2021      2   28          6              1          1
# 18246    23    85.0  2021      2   28          6              1          1
#
#         timeOfDay Seasons
# 0         Morning  Winter
# ...

# %%
sns.barplot(x=df['Seasons'],y=df['demand'],palette="Set2")

# %%
sns.barplot(x=df['timeOfDay'],y=df['demand'],palette="Pastel1")

# %%
sns.barplot(x=df['hour'],y=df['demand'],palette="coolwarm")

# %%
df.columns # For all attributes
# Out:
# Index(['hour', 'demand', 'year', 'month', 'day', 'dayofweek', 'isquarterdate',
#        'isweekend', 'timeOfDay', 'Seasons'],
#       dtype='object')
